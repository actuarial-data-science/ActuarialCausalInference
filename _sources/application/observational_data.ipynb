# %% [markdown]
# # Observational Data
#
# Most data available to an actuary is **observational**: policyholders, patients, or drivers are *not* randomly assigned to a treatment (a wellness programme, a discount, a new pricing rule). Instead, who receives the treatment is driven by self-selection, eligibility rules, or underwriting decisions — the very factors that also influence the outcome. This is what makes naive comparisons misleading.
#
# This notebook walks through the practical workflow for turning observational data into a credible causal statement. Using a synthetic insurance-style dataset, we:
#
# 1. **Encode our assumptions** in a causal graph (DAG)
# 2. **Validate each of the four identification assumptions** — {prf:ref}`consistency`, {prf:ref}`sutva`, {prf:ref}`positivity`, and {prf:ref}`exchangeability` — graphically and statistically, using the diagnostics and sensitivity tools from {doc}`../tutorial/sensitivity`.
# 3. **Show what to do when an assumption fails**, mapping each violation to a concrete remedy (trimming, overlap weighting, sensitivity analysis) following {doc}`../tutorial/debias`.
#
# The goal is a reusable checklist: before reporting any treatment effect from observational data, an actuary should be able to point to the diagnostic that supports — or qualifies — each assumption.

# %% [markdown]
# ### Toolkit: Dealing with Violated Assumptions
#
# Recall from {doc}`../tutorial/assumptions` that an observational study can be treated as a *conditionally randomized experiment* only if four assumptions hold. Each one can be probed — some directly from data, others only indirectly:
#
# | Assumption | What it requires | How we validate it here | If violated → remedy |
# |---|---|---|---|
# | {prf:ref}`consistency` | The treatment is well-defined (one version) | Re-estimate the effect by treatment sub-type | Split into well-defined treatments; estimate each separately |
# | {prf:ref}`sutva` | No interference between units | Correlate control outcomes with neighbours' treatment intensity | Cluster / partial-interference models; randomise at group level |
# | {prf:ref}`positivity` | Every covariate profile *can* receive both arms | Propensity-score overlap (box / mirror plots) | **Restrict** (trim to common support) or **reweight** (overlap weights) |
# | {prf:ref}`exchangeability` | No unmeasured confounding given $X$ | Balance (SMD / Love plot) + sensitivity analysis | Richer adjustment set, instrumental variables, or report robustness (E-value, RV, critical Γ) |
#
# The first three leave **detectable footprints** in the data. The fourth — exchangeability — is fundamentally untestable, so we instead ask *how robust* our conclusion is to a hypothetical unmeasured confounder (E-values, partial $R^2$, Rosenbaum bounds, placebo tests). When a check fails, we reach for the matching tool from the de-biasing toolkit ({doc}`../tutorial/debias`): **restrict** (trim to the overlap region), **reweight** (overlap weights), **model the structure** (DAG-guided adjustment), or **report a sensitivity bound**.
#
#
# ### The end-to-end pipeline
#
# ```{figure} figs/pipeline_observational.svg
# :name: obs-pipeline
# :width: 100%
#
# The identification workflow for observational data: encode assumptions in a DAG, validate each of the four assumptions, and — if any is violated — apply the matching remedy and re-estimate with a robustness check before reporting transparently.
# ```

# %%
import os
import warnings

import networkx as nx
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np
import pandas as pd
from scipy.stats import ttest_ind
import plotly.graph_objects as go
import plotly.subplots as sp
from scipy.special import expit
from IPython.display import SVG, display
from utils import *
import plotly


np.seterr(all="ignore")
warnings.filterwarnings("ignore", category=RuntimeWarning)

plotly.offline.init_notebook_mode(connected=True)


# Folder for the exported causal-graph SVG figures
FIG_DIR = os.path.join("figs")
os.makedirs(FIG_DIR, exist_ok=True)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.6.0.min"</script>

# %% [markdown]
# ## A Synthetic Insurance Example
#
# We simulate $N = 1000$ policyholders enrolled (or not) in a voluntary **wellness programme** ($T$). Ten covariates $X_1, \dots, X_{10}$ describe each policyholder (age, risk indicators, etc.), and the outcome $Y$ is a cost/health score we hope the programme improves. Because the data is *synthetic*, we know the ground truth — the true average treatment effect is `ATE = 5.0` — which lets us check whether each diagnostic behaves as expected.
#
# We deliberately build in the imperfections an actuary meets in practice:
#
# - **Two propensity regimes:** a *good* one where enrolment depends only mildly on covariates (positivity holds), and a *violated* one where certain profiles are almost always or never enrolled (positivity fails).
# - **An unobserved confounder** $U$ that drives both enrolment and the outcome but is *not* in the covariate set — the source of potential exchangeability violations.
# - A **treatment sub-type** (two delivery modes of the same programme) to probe consistency, and a **group structure** with spillovers to probe SUTVA.

# %%
# --- 1. Synthetic Data Generation ---
N = 1000  # Number of observations
ATE = 5.0 # Average Treatment Effect
np.random.seed(42)

# Coefficients for the causal model
beta_x1_t = 0.5
beta_x2_t = 1.0
beta_x1_y = 1.0
beta_x2_y = 2.0
intercept_t = -1.5
intercept_y = 10.0
beta_x1_t_v = 5.0  # High coefficient for violation
beta_x2_t_v = 3.0  # High coefficient for violation
intercept_t_v = 0.0
beta_u = 0.8       # strength of the UNOBSERVED confounder on treatment uptake

# Generate Covariates (X)
X1 = np.random.normal(loc=40, scale=10, size=N)
X2 = np.random.binomial(n=1, p=0.4, size=N)

# Generate 8 more covariates
X3 = np.random.uniform(low=0, high=100, size=N)
X4 = np.random.normal(loc=10, scale=2, size=N)
X5 = np.random.randint(low=0, high=5, size=N) # Categorical-like
X6 = np.random.gamma(shape=2, scale=2, size=N)
X7 = np.random.poisson(lam=3, size=N)
X8 = np.random.exponential(scale=1, size=N)
X9 = np.random.normal(loc=50, scale=5, size=N)
X10 = np.random.binomial(n=1, p=0.7, size=N)

# UNOBSERVED confounder U: drives BOTH enrolment and the outcome, but is NOT
# part of the covariate set the analyst gets to use. It is the hidden reason
# why exchangeability can never be fully verified from data.
U = np.random.normal(loc=0, scale=1, size=N)

# Calculate Propensity Scores

# 1. Good Positivity (Mild dependence on X) + hidden dependence on U
# Add new covariates to the linear predictor for 'good' treatment assignment
linear_predictor_t = (
    intercept_t
    + (beta_x1_t * (X1 - X1.mean()) / X1.std())
    + (beta_x2_t * X2)
    + (0.1 * (X3 - X3.mean()) / X3.std()) # Small effect
    + (0.2 * (X4 - X4.mean()) / X4.std()) # Small effect
    + (beta_u * U)                         # hidden confounding via U
)
prob_t = expit(linear_predictor_t)
T = np.random.binomial(n=1, p=prob_t, size=N)

# 2. Bad Positivity (Extreme dependence on X)
# Add new covariates to the linear predictor for 'violate' treatment assignment (with higher coefficients)
linear_predictor_t_v = (
    intercept_t_v
    + (beta_x1_t_v * (X1 - X1.mean()) / X1.std())
    + (beta_x2_t_v * X2)
    + (1.5 * (X3 - X3.mean()) / X3.std()) # Larger effect
    + (1.0 * (X4 - X4.mean()) / X4.std()) # Larger effect
    + (0.8 * X5) # Larger effect for categorical
)
prob_t_violate = expit(linear_predictor_t_v)
T_Violate = np.random.binomial(n=1, p=prob_t_violate, size=N)

# Create DataFrame including all covariates
data = pd.DataFrame({
    'X1': X1,
    'X2': X2,
    'X3': X3,
    'X4': X4,
    'X5': X5,
    'X6': X6,
    'X7': X7,
    'X8': X8,
    'X9': X9,
    'X10': X10,
    'U_unobserved': U,
    'T_Treatment': T,
    'T_Violate_Positivity': T_Violate,
    'P_Propensity_Score_Good': prob_t,
    'P_Propensity_Score_Violate': prob_t_violate
})

data.head(5)
# Out:
#           X1  X2         X3         X4  X5        X6  X7        X8         X9  \
# 0  44.967142   0  21.906881   8.786599   4  2.594468   2  0.123125  52.142193
# 1  38.617357   0   3.672136  10.422567   3  2.009630   4  0.864453  47.578047
# 2  46.476885   1  10.802575  12.400158   1  3.812620   0  0.453005  47.091020
# 3  55.230299   1  33.886065   9.016195   4  0.319852   4  0.083726  49.157490
# 4  37.658466   0  80.258568   6.246895   1  1.507062   1  2.180253  44.745755
#
#    X10  U_unobserved  T_Treatment  T_Violate_Positivity  \
# 0    0     -0.085092            0                     1
# 1    1     -0.814118            0                     0
# 2    0     -0.749608            1                     1
# 3    1      0.232870            1                     1
# 4    1     -1.635828            0                     0
#
#    P_Propensity_Score_Good  P_Propensity_Score_Violate
# 0                 0.176659                    0.973667
# 1                 0.087018                    0.357944
# 2                 0.336216                    0.997901
# 3                 0.575266                    0.999997
# 4                 0.039227                    0.325387

# %%
# --- 2. Outcomes used to validate the four assumptions ---
X1_std = (X1 - X1.mean()) / X1.std()

# Structural outcome model:  Y = baseline + ATE*T + observed confounders + U + noise.
# Because U is omitted from any analysis, it induces *unmeasured* confounding.
noise_y = np.random.normal(loc=0, scale=2.0, size=N)
Y = (
    intercept_y
    + ATE * T
    + beta_x1_y * X1_std
    + beta_x2_y * X2
    + 1.5 * U
    + noise_y
)

# Treatment SUB-TYPE -> probes CONSISTENCY.
# The single label "T = 1" actually hides two delivery modes (0 and 1) of the
# programme; mode 1 is slightly more effective, so the treatment is not a single
# well-defined intervention.
Treatment_Subtype = np.where(T == 1, np.random.binomial(1, 0.5, N), -1)  # -1 = untreated
Y = Y + np.where(Treatment_Subtype == 1, 1.5, 0.0)

# GROUP structure with spillovers -> probes SUTVA (no interference).
# Untreated policyholders benefit when more of their group is treated.
n_groups = 200
Group_ID = np.random.randint(0, n_groups, size=N)
group_treat_rate = pd.Series(T).groupby(Group_ID).transform('mean').values
Y_Spillover = Y + 3.0 * group_treat_rate * (1 - T)

# NEGATIVE-CONTROL outcome -> used for the placebo / falsification test.
# Driven by the confounders and U, but by construction NOT by the treatment T.
Y_Negative_Control = (
    5.0
    + beta_x1_y * X1_std
    + beta_x2_y * X2
    + 1.5 * U
    + np.random.normal(loc=0, scale=2.0, size=N)
)

# Outcome generated under the VIOLATED-positivity assignment T_Violate, with the
# SAME causal effect (ATE) and observed confounding. Used in the positivity
# remedy section so the comparison against the known ATE is meaningful.
Y_Violate = (
    intercept_y
    + ATE * T_Violate
    + beta_x1_y * X1_std
    + beta_x2_y * X2
    + np.random.normal(loc=0, scale=2.0, size=N)
)

data['Y'] = Y
data['Treatment_Subtype'] = Treatment_Subtype
data['Group_ID'] = Group_ID
data['Y_Spillover'] = Y_Spillover
data['Y_Negative_Control'] = Y_Negative_Control
data['Y_Violate'] = Y_Violate

data[['T_Treatment', 'Treatment_Subtype', 'Group_ID', 'Y', 'Y_Negative_Control']].head()
# Out:
#    T_Treatment  Treatment_Subtype  Group_ID          Y  Y_Negative_Control
# 0            0                 -1       137  12.163872            4.647940
# 1            0                 -1       180   9.132436            7.689888
# 2            1                  1       178  15.482761            5.683803
# 3            1                  1       196  18.293101            6.803677
# 4            0                 -1        13   6.944880            3.454130

# %%
# DAG Plot
causal_model = {
    'X1 -> T': beta_x1_t,
    'X2 -> T': beta_x2_t,
    'X1 -> Y': beta_x1_y,
    'X2 -> Y': beta_x2_y,
    'T -> Y': ATE
}

print("Causal Model (DAG Structure and Weights):")
for path, weight in causal_model.items():
    print(f"{path}: {weight}")

causal_model_violate_positivity = {
    'X1 -> T': beta_x1_t_v,
    'X2 -> T': beta_x2_t_v,
    'X1 -> Y': beta_x1_y,
    'X2 -> Y': beta_x2_y,
    'T -> Y': ATE
}

print("Causal Model with violated positivity(DAG Structure and Weights):")
for path, weight in causal_model_violate_positivity.items():
    print(f"{path}: {weight}")
# Out:
# Causal Model (DAG Structure and Weights):
# X1 -> T: 0.5
# X2 -> T: 1.0
# X1 -> Y: 1.0
# X2 -> Y: 2.0
# T -> Y: 5.0
# Causal Model with violated positivity(DAG Structure and Weights):
# X1 -> T: 5.0
# X2 -> T: 3.0
# X1 -> Y: 1.0
# X2 -> Y: 2.0
# T -> Y: 5.0

# %% [markdown]
# ## Encoding Assumptions in a Causal Graph
#
# Before touching the data we make our assumptions explicit with a **directed acyclic graph** (DAG). The DAG is the contract: it states which variables confound the treatment–outcome relationship and therefore which must be adjusted for ({prf:ref}`backdoor-criterion`).
#
# We export each graph as a stand-alone **`*.svg`** file (vector graphics stay crisp at any zoom in the rendered book) and embed it below.
#
# - **Left — the analyst's model:** observed confounders $X_1, X_2$ open backdoor paths $X \rightarrow T$ and $X \rightarrow Y$. Adjusting for them closes the paths, so the effect of $T$ on $Y$ is identified.
# - **Right — the uncomfortable reality:** an *unobserved* confounder $U$ (dashed) also drives both $T$ and $Y$. Its backdoor path $T \leftarrow U \rightarrow Y$ (red, dashed) **cannot** be closed by adjustment, which is exactly what threatens {prf:ref}`exchangeability`.
#
# Taking the contract seriously means adjusting for **exactly** $\{X_1, X_2\}$ — no more, no less. The other measured covariates are *not* confounders: in the data-generating process $X_3, X_4$ influence treatment only (they are **instruments**) and $X_5,\dots,X_{10}$ are pure noise. Throwing them into the adjustment set is not a harmless "kitchen-sink" safeguard — conditioning on an instrument **amplifies** the bias from the unobserved $U$ (Z-bias / bias amplification; [Pearl, 2011](https://ftp.cs.ucla.edu/pub/stat_ser/r348.pdf); [Myers et al., 2011](https://doi.org/10.1093/aje/kwr364)). We measure balance on all ten (below), but we *adjust* only on the two the DAG licenses.

# %%
# Build two causal graphs and export them as embeddable SVG files.

# Layout shared by both graphs
base_pos = {
    'X1': (-0.6, 1.0),
    'X2': (0.6, 1.0),
    'T': (-1.0, -0.3),
    'Y': (1.0, -0.3),
}
base_styles = {'X1': 'confounder', 'X2': 'confounder', 'T': 'treatment', 'Y': 'outcome'}

# (a) The analyst's model: only observed confounders. All backdoor paths closable.
svg_observed = draw_causal_graph_svg(
    edges=[('X1', 'T'), ('X1', 'Y'), ('X2', 'T'), ('X2', 'Y'), ('T', 'Y')],
    positions=base_pos,
    node_styles=base_styles,
    filepath=os.path.join(FIG_DIR, 'dag_observational.svg'),
    title='Identifiable: adjust for X1, X2',
    legend_types=['confounder', 'treatment', 'outcome'],
)

# (b) Reality: an unobserved confounder U opens a backdoor path that adjustment
#     cannot close (its edges are drawn as dashed-red 'biasing' arrows).
pos_u = dict(base_pos, U=(0.0, 1.9))
styles_u = dict(base_styles, U='unobserved')
svg_unobserved = draw_causal_graph_svg(
    edges=[('X1', 'T'), ('X1', 'Y'), ('X2', 'T'), ('X2', 'Y'), ('T', 'Y'),
           ('U', 'T', 'biasing'), ('U', 'Y', 'biasing')],
    positions=pos_u,
    node_styles=styles_u,
    filepath=os.path.join(FIG_DIR, 'dag_unobserved.svg'),
    title='Not identifiable: U is unobserved',
    legend_types=['confounder', 'treatment', 'outcome', 'unobserved'],
)

print('Saved SVG figures:')
print(' -', svg_observed)
print(' -', svg_unobserved)

# Embed the vector graphics side by side
display(SVG(svg_observed))
display(SVG(svg_unobserved))
# Out:
# Saved SVG figures:
#  - figs/dag_observational.svg
#  - figs/dag_unobserved.svg

# %% [markdown]
# ## Assumption 1 — Consistency
#
# {prf:ref}`consistency` requires the treatment to be **well-defined**: a single, unambiguous intervention. If "enrolled in the programme" secretly bundles several different delivery modes, then $Y(1)$ is not a single quantity and the estimated effect is an uninterpretable average.
#
# **Diagnostic.** We re-estimate the (regression-adjusted) effect *separately for each pre-labelled treatment sub-type*, comparing each against the common control group. Read this as a *suggestive* check, not a formal test of {prf:ref}`consistency`: unequal effects across sub-types are equally compatible with (a) a genuine consistency violation — the label bundling distinct manipulations with different $Y(1)$ — and (b) consistency holding perfectly while the CATE simply varies by sub-type (ordinary effect modification). This statistic cannot separate the two (VanderWeele, 2009, *Biometrics* 65(4):1189–1196). Consistency is ultimately a question about the *treatment definition*, so only substantive domain judgement about whether the label bundles multiple versions can confirm a violation; conversely, a stable effect across the sub-types we happen to observe is reassuring but cannot certify consistency, as it says nothing about unmeasured versions. Splitting into separately-defined treatments is warranted when large variation coincides with a substantive reason to believe the sub-types are genuinely different interventions.

# %%
# Re-estimate the effect within each treatment sub-type (delivery mode).
# Adjustment set = exactly the confounders the DAG declares: {X1, X2}. In the DGP
# X3 and X4 affect treatment only (they are INSTRUMENTS) and X5–X10 are pure noise.
# Adjusting for instruments is contraindicated: it amplifies the bias from the
# unobserved confounder U (Z-bias / bias amplification; Pearl 2011; Myers et al.
# 2011; Ding, VanderWeele & Robins 2017). We therefore adjust for what — and only
# what — the DAG (the "contract") licenses.
covariates_adj = ['X1', 'X2']
consistency_tbl = consistency_diagnostic(
    data, treatment='T_Treatment', outcome='Y',
    subtype_col='Treatment_Subtype', covariates=covariates_adj,
)
display(consistency_tbl.round(3))

# Visualise the effect per sub-type with ±1.96 SE error bars
fig = go.Figure()
fig.add_trace(go.Bar(
    x=consistency_tbl['Group'], y=consistency_tbl['Effect'],
    error_y=dict(type='data', array=1.96 * consistency_tbl['Std. Error']),
    marker_color=['#555555', '#1f77b4', '#ff7f0e'][:len(consistency_tbl)],
))
fig.add_hline(y=ATE, line_dash='dash', line_color='green',
              annotation_text=f'True ATE = {ATE}', annotation_position='top left')
fig.update_layout(title_text='Estimated effect by treatment sub-type',
                  yaxis_title='Effect on Y', xaxis_title='')
show(fig)
# Out:
#               Group  Effect  Std. Error  n_treated
# 0  Overall (pooled)   6.785       0.183        267
# 1        Sub-type 0   6.111       0.234        137
# 2        Sub-type 1   7.460       0.240        130
# <div style="height:100%; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="17287226-869d-46b7-af99-ece1f7396285" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("17287226-869d-46b7-af99-ece1f7396285")) {                    Plotly.newPlot(                        "17287226-869d-46b7-af99-ece1f7396285",                        [{"error_y":{"array":{"dtype":"f8","bdata":"fw7tQsnt1j9nBZ7lAVXdP00PH\u002fFeJt4\u002f"},"type":"data"},"marker":{"color":["#555555","#1f77b4","#ff7f0e"]},"x":["Overall (pooled)","Sub-type 0","Sub-type 1"],"y":{"dtype":"f8","bdata":"CpIdtT8kG0CsST7+HnIYQJHiUaJC1x1A"},"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}} ...

# %% [markdown]
# ```{note} Interpretation — consistency
# :class: dropdown
#
# The two delivery modes give **different** effects, so the single label *"treated"* is **not** a well-defined treatment — {prf:ref}`consistency` is questionable.
#
# **Remedy:** define each delivery mode as its own treatment and estimate the effects separately.
# ```

# %% [markdown]
# ## Assumption 2 — SUTVA (No Interference)
#
# {prf:ref}`sutva` requires that one unit's treatment does **not** affect another unit's outcome. In insurance this fails through *spillovers*: a group discount changes behaviour across a whole household or employer group, so untreated members are indirectly affected.
#
# **Diagnostic.** For every policyholder we compute the **leave-one-out treatment intensity** of their group (the share of *other* members who are treated). Under no interference, the outcomes of *control* units should be uncorrelated with this intensity. A significant correlation is direct evidence of spillover.

# %%
# Run the interference diagnostic on two outcomes:
#  - Y           : generated WITHOUT spillover (SUTVA holds)
#  - Y_Spillover : untreated units benefit from treated neighbours (SUTVA violated)
r_clean, p_clean, _ = interference_diagnostic(data, 'Group_ID', 'T_Treatment', 'Y')
r_spill, p_spill, ctrl_spill = interference_diagnostic(data, 'Group_ID', 'T_Treatment', 'Y_Spillover')

print(f"No-spillover outcome  Y           : r = {r_clean:+.3f}  (p = {p_clean:.3f})")
print(f"Spillover outcome     Y_Spillover : r = {r_spill:+.3f}  (p = {p_spill:.3f})")

fig = sp.make_subplots(rows=1, cols=2, subplot_titles=(
    'SUTVA holds (Y)', 'SUTVA violated (Y_Spillover)'))
for col, (outcome, ctrl) in enumerate(
        [('Y', interference_diagnostic(data, 'Group_ID', 'T_Treatment', 'Y')[2]),
         ('Y_Spillover', ctrl_spill)], start=1):
    fig.add_trace(go.Scatter(
        x=ctrl['cluster_treat_intensity'], y=ctrl[outcome], mode='markers',
        marker=dict(color='forestgreen', size=5, opacity=0.5), showlegend=False,
    ), row=1, col=col)
    # OLS trend line
    m, b = np.polyfit(ctrl['cluster_treat_intensity'], ctrl[outcome], 1)
    xs = np.linspace(0, 1, 50)
    fig.add_trace(go.Scatter(x=xs, y=m * xs + b, mode='lines',
                             line=dict(color='red', width=2), showlegend=False),
                  row=1, col=col)
fig.update_xaxes(title_text="Neighbours' treatment intensity")
fig.update_yaxes(title_text='Control-unit outcome', col=1)
fig.update_layout(height=400,
                  title_text='Interference check: control outcomes vs. neighbours’ treatment')
show(fig)
# Out:
# No-spillover outcome  Y           : r = -0.035  (p = 0.343)
# Spillover outcome     Y_Spillover : r = +0.136  (p = 0.000)
# <div style="height:400px; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="b44c7479-4c38-4194-af7b-b9ca3efbb365" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b44c7479-4c38-4194-af7b-b9ca3efbb365")) {                    Plotly.newPlot(                        "b44c7479-4c38-4194-af7b-b9ca3efbb365",                        [{"marker":{"color":"forestgreen","opacity":0.5,"size":5},"mode":"markers","showlegend":false,"x":{"dtype":"f8","bdata":"VVVVVVVV1T8AAAAAAAAAAFVVVVVVVcU\u002fVVVVVVVVxT8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAXXXTRRRfdPwAAAAAAAOA\u002fmpmZmZmZ2T\u002fbtm3btm3bP1VVVVVVVdU\u002fAAAAAAAAwD8AAAAAAAAAAJqZmZmZmck\u002fAAAAAAAAAAAAAAAAAAAAAFVVVVVVVdU\u002fkiRJkiRJ4j8AAAAAAADQP5qZmZmZmdk\u002fAAAAAAAA4D8AAAAAAAAAAAAAAAAAAAAAVVVVVVVV1T8AAAAAAADQPwAAAAAAAAAAAAAAAAAAAABVVVVVVVXlP5IkSZIkScI\u002fAAAAAAAA4D8AAAAAAAAAAJqZmZmZmck\u002fkiRJkiRJwj+3bdu2bdvWP9u2bdu2bds\u002fAAAAAAAAAABVVVVVVVXVP7dt27Zt29Y\u002fmpmZmZmZyT9VVVVVVVXVPwAAAAAAANA\u002fAAAAAAAA0D+amZmZmZnJP0YXXXTRRcc\u002fVVVVVVVV1T8AAAAAAAAAAAAAAAAAAAAAAAAAAAAA0D8zMzMzMzPTP5IkSZIkSdI\u002fmpmZmZmZ2T+amZmZmZnJP5IkSZIkScI\u002fVVVVVVVV1T9VVVVVVVXVPwAAAAAAAAAAAAAAAAAA2D8AAAAAAADoP5qZmZmZmck\u002fAAAAAAAA0D8AAAAAAADwP9u2bdu2bds\u002fmpmZmZmZyT8AAAAAAAAAAAAAAAAAAOA\u002f27Zt27Zt2z8AAAAAAAAAAAAAAAAAAAAAAAAAAAAA4D+amZmZmZnJPwAAAAAAAAAAAAAAAAAA4D8AAAAAAAAAAAAAAAAAAMA\u002fAAAAAAAAAAAAAAAAAAAAAFVVVVVVVcU\u002fAAAAAAAAAAAAAAAAAADQP1VVVVVVVdU\u002fAAAAAAAAAAAAAAAAAAAAAJqZmZmZmdk\u002fAAAAAAAA2D8AAAAAAAAAAJqZmZmZmck\u002fAAAAAAAA0D8AAAAAAADgP9u2bdu2bds\u002fAAAAAAAA2D9VVVVVVVXFPwAAAAAAAOA\u002fAAAAAAAA4D8AAAAAAADAPwAAAAAAAAAAAAAAAAAA4D8cx3Ecx3G8P1VVVVVVVeU\u002fAAAAAAAA4D9VVVVVVVXVPwAAAAAAAAAAkiRJkiRJ0j8AAAAAAADYP1VVVVVVVeU\u002fkiRJkiRJ0j8zMzMzMzPTPwAAAAAAAAAAAAAAAAAAAAAAAAAAAADQP5qZmZmZmdk\u002fVVVVVVVVxT8AAAAAAAAAAAAAAAAAANg\u002fVVVVVVVVxT9VVVVVVVXFPwAAAAAAAPA\u002fVVVVVVVV5T8zMzMzMzPTPwAAAAAAAOA\u002ft23btm3b1j8AAAAAAAAAAFVVVVVVVcU\u002fAAAAAAAAAACamZmZmZnZPwAAAAAAAAAAVVVVVVVV1T+amZmZmZnJP5qZmZmZmdk\u002fmpmZmZmZyT8AAAAAAADQP1VVVVVVVdU\u002fVVVVVVVV1T8AAAAAAADYP1VVVVVVVcU\u002fMzMzMzMz4z+amZmZmZnJPwAAAAAAANg\u002fVVVVVVVV1T9VVVVVVVXVP9u2bdu2bds\u002fAAAAAAAA6D8AAAAAAADYPwAAAAAAAOg\u002fVVVVVVVV1T+amZmZmZnZPwAAAAAAAAAAVVVVVVVV1T8AAAAAAAAAAEYXXXTRRcc\u002fVVVVVVVVxT8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAwD8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAADYP1VVVVVVVdU\u002fAAAAAAAA0D8AAAAAAAAAADMzMzMzM+M\u002fAAAAAAAA4D8AAAAAAADgP7dt27Zt29Y\u002fVVVVVVVV1T8AAAAAAAAAAFVVVVVVVdU\u002fAAAAAAAAAAAzMzMzMzPjP1VVVVVVVcU\u002fVVVVVVVV5T9VVVVVVVXFPwAAAAAAAOA\u002fMzMzMzMz4z9VVVVVVVXVP5qZmZmZmdk\u002fVVVVVVVVxT8XXXTRRRfdPwAAAAAAAAAAAAAAAAAAAAAAAAAAAADQPwAAAAAAANA\u002fAAAAAAAA6D8AAAAAAAAAAJIkSZIkScI\u002fVVVVVVVVxT+amZmZmZnZPzMzMzMzM+M\u002fAAAAAAAA0D+amZmZmZnJPwAAAAAAAPA\u002fmpmZmZmZ2T9VVVVVVVXVPwAAAAAAANA\u002fVVVVVVVVxT8AAAAAAADoPwAAAAAAAOA\u002fAAAAAAAAAABVVVVVVVXlP5qZmZmZmdk\u002fVVVVVVVV1T8AAAAAAADgPwAAAAAAANA\u002fMzMzMzMz0z8AAAAAAADQPwAAAAAAAAAAAAAAAAAAAACamZmZmZnJP5qZmZmZmck\u002fVVVVVVVV1T9VVVVVVVXFP1VVVVVVVdU\u002fHMdxHMdxvD+amZmZmZnJP1VVVVVVVdU\u002fmpmZmZmZ2T+amZmZmZnZPwAAAAAAAAAAAAAAAAAAAACamZmZmZnJP5qZmZmZmck\u002fAAAAAAAA0D8AAAAAAAAAAAAAAAAAAAAAAAAAAAAA6D9VVVVVVVXVP1VVVVVVVdU\u002fAAAAAAAAAACamZmZmZnZP5IkSZIkScI\u002fAAAAAAAA0D+amZmZmZnJPzMzMzMzM+M\u002fVVVVVVVV1T8AAAAAAAAAAEYXXXTRRcc\u002fVVVVVVVV5T8AAAAAAAAAAJqZmZmZmdk\u002fmpmZmZmZyT9VVVVVVVXVPwAAAAAAAMA\u002fmpmZmZmZyT8AAAAAAADQP7dt27Zt29Y\u002fAAAAAAAA4D8AAAAAAADgPwAAAAAAAMA\u002ft23btm3b5j8zMzMzMzPjP5IkSZIkScI\u002fAAAAAAAA0D9GF1100UXHP1VVVVVVVdU\u002fAAAAAAAAAACSJEmSJEnCP5qZmZmZmck\u002fVVVVVVVV1T+amZmZmZnJPxdddNFFF90\u002fVVVVVVVV5T+amZmZmZnZPwAAAAAAANA\u002fmpmZmZmZyT+amZmZmZnZPwAAAAAAANA\u002fAAAAAAAAAAAAAAAAAAAAAFVVVVVVVdU\u002fAAAAAAAA4D+SJEmSJEnCP5qZmZmZmdk\ ...

# %% [markdown]
# ```{note} Interpretation — SUTVA
# :class: dropdown
#
# A flat cloud (left) is consistent with **no interference**; the upward slope (right) reveals **spillover**, so {prf:ref}`sutva` is violated.
#
# **Remedy:** assign and analyse treatment at the **group level** (partial-interference or cluster models).
# ```

# %% [markdown]
# ## Assumption 3 — Positivity
#
# {prf:ref}`positivity` requires that *every* covariate profile has a non-trivial chance of receiving **both** treatment and control: $0 < \pi(x) < 1$. It is the most **directly diagnosable** assumption — we simply inspect the estimated propensity scores $\hat{\pi}(x)$ by treatment group and look for **non-overlap** (mass piling up near 0 or 1).
#
# The box / mirror plots below contrast our two regimes. Under *good* positivity the treated and control score distributions overlap broadly. Under the *violated* regime they separate: some profiles are almost always (or never) enrolled, leaving regions with no comparable units. There, inverse-probability weights $1/\hat{\pi}(x)$ explode and estimates become unstable ({doc}`../tutorial/debias`).

# %%
# --- Plotly Boxplot Execution and Display ---
# Create boxplot for Good Overlap
fig_boxplot_good = plot_propensity_score_boxplots(
    data,
    'P_Propensity_Score_Good',
    'T_Treatment',
    'Boxplots of Propensity Scores: Good Positivity'
)
show(fig_boxplot_good)

# Create boxplot for Severe Violation
fig_boxplot_violate = plot_propensity_score_boxplots(
    data,
    'P_Propensity_Score_Violate',
    'T_Violate_Positivity',
    'Boxplots of Propensity Scores: Violation of Positivity'
)
show(fig_boxplot_violate)
# Out:
# <div style="height:100%; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="cb454b86-71fb-4e81-b0d8-96c6fce4f627" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cb454b86-71fb-4e81-b0d8-96c6fce4f627")) {                    Plotly.newPlot(                        "cb454b86-71fb-4e81-b0d8-96c6fce4f627",                        [{"boxpoints":false,"hovertemplate":"\u003cb\u003e%{y.name}\u003c\u002fb\u003e\u003cbr\u003eMin: %{y.min:.4f}\u003cbr\u003eQ1: %{y.q1:.4f}\u003cbr\u003eMedian: %{y.median:.4f}\u003cbr\u003eQ3: %{y.q3:.4f}\u003cbr\u003eMax: %{y.max:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#98C21F"},"name":"Control","y":{"dtype":"f8","bdata":"hk0wqb+cxj85942O1Ea2P8muyyGXFaQ\u002f86dVPsvS0j\u002fH73g\u002fet3hP4wRdIu5uNM\u002fYY7+CQLO1D9sp9Q8FFbWP99ZokexPbc\u002fTvUnNDC0rD8pZ+yQPJ7APzICms+nj8Q\u002fzqozz5gKpz\u002fYH2KcVarLP9LAXXG4Uck\u002fBBUxEwifyz+2uWeeS8K3Pzoypq\u002fOIdM\u002fpUMjgdDm0D+c3t1P9ey9P2inDPh1298\u002fFY9UxWrCnD8Jw1HpirvUP9MpOmh4fbc\u002fsM5kEsPbuz+T1eCUQtfSP\u002f5W\u002fr9+9tU\u002fXXeuANqmwj\u002f\u002f6X45NLPYP\u002fBASR5aidQ\u002fVKbtecmS0T9rYCPRscrJP5XKm0xRtrU\u002f3oID3WC32z\u002fxdQ6In8\u002fPP5jTHXKWI9A\u002flL2+WfERoz8cMHpXz+HiPzhRlqKXL+E\u002fxFw4Id153z9k+LJNwsu8PyXsbQwRGek\u002fvrsc47YVwj9hTQ06OEOlP3Q78EkrDqg\u002fpklSBlp81D+N5fppHTDMP0Zwetp8ods\u002fz0EWncln4z+czd+JiEy+P7\u002fq+\u002fF487Q\u002fD3o4EEpP1j\u002fWT801obO+P0\u002fGmuSRA+Q\u002fcFLoX1Mhxj8agBr1XBnPP8YU4Lu45qo\u002fNlsFAmTXvj9CUvEd7OamP\u002fJrNSpKPa8\u002f5wdQCqz4xT9xtxWYC3zHP04P9l1KVtk\u002fr8yyJFJy2T\u002fhEQrYiTzWP8DpT2Kwgqw\u002fJqhBdLZtrj\u002fdT202krXMP+6kXXolAOE\u002f7G2aHDEIxT9xbuZegkHFP+q4tRAi98M\u002fXil4V6vwxz+RItyIi8TKPzHLGqquCeA\u002fDjF5K4XD0z+bHzhB71zSP6HagTP1BtU\u002fDVWYo0FT4T98aSO9izbfP9mgJ\u002fnvO6s\u002f41XCrEeWwT\u002fc1WcLerfIP7hpF2HSNqA\u002fqI7RB9nL4T8fd8+M2KjRPy2Zl0\u002f008I\u002fuiwSubWOzz\u002fU5PUfXXDSPypa0941kqI\u002fOguf21u\u002fxD97y84AJl7RPzo7fd0Jjs0\u002fSIWA3PL+1j\u002fuhjbN+sXIP8eBXcrRJ+A\u002fo1NKlKQ0vz+a1xv454XCP+JwwPZyhLY\u002fbpq3lYMHtj8qzUBrFdbZP\u002f1R+NRcktI\u002f3Jbzd1AGtj9Aw+NLM3S8P9SxQD8Qerg\u002fhCl7wa5HyT\u002fSnHPsRr\u002fPP6VpA3lNcbw\u002fgrxS7ssZwz9PQF6WJ8fgP1dOgOkrktY\u002f0rnWAWRq1z+0iGqEU3HbP3OZQA6Sr9I\u002fkffHNh8R4j\u002fKiQiC15DEPxSANmIbbdg\u002filKjWedUzj+pzblu8jrWP+xGqwForuU\u002fqF3bAEaIvD\u002f\u002famnWrpG3Pw3vsDCdEdU\u002f\u002fdx8m5Hduj+TsxtXMX+iPy1Pb2ChncY\u002f51x4MqiFxz+k+45kDc7VP2trsdmoANo\u002fMYBAviNVpT\u002f3LZHXUT6oP+HxuvWEzrk\u002fubFfWOwLwj98xKxPluDhP\u002fhzPiyo6tA\u002fEZ2oBJWlyD9Rv15Lyam+P0cQiey1Ad8\u002fnoGiempx2T8xX1FBUsK8P1BedeeBj88\u002fQgpCxJpJsD950KWlDC3fP8S4zNu2MtA\u002f6wuG6xjryj++xFEHXz3iP4qY0y4sjqQ\u002fSTJ\u002fn2PoxT+Z\u002fC\u002fSDIzQP1VtBw9Qns0\u002fhzcPlRYE2T+2C8HgPvLLP8B\u002f5aXI\u002fcw\u002f1LjiT7VhyD8s8Wdsf0KzP4FySR5kg8s\u002fd\u002fBVGEHgwz9PsnTunRrYP12NwnLpTLw\u002f27h1fDBGzD\u002fjDb\u002fDsBbWP++zJJojWL0\u002fTBBoiQIwwj9D2+Z6zL25P9v4dD\u002fCe8E\u002f85Ql7XLVyz8rffGlaIDeP+vrWNEmkZw\u002f2CD6qWwC4z+iajHhf\u002fjaPx2Goad7vtc\u002f\u002fPX7auX1uj\u002ftpFYNkaLTP7QCc7uGWdA\u002f4xmTpyQR0j+NWDgsTBHCP0yXmD2q2Mo\u002f\u002f6y4ZZCOrj9BMfqNiRfMP8fTNTjtmNE\u002fxq3uyD9ryz\u002fZlKKqJvPUPz0noD9BT9A\u002f5LmWHbN5yz9AzyvFlSTgP2ep8wIExck\u002f2lEq0fkXxj9UlPGvJQjSP2c\u002fsz6pxso\u002fpT0qaJENvz9x76px\u002fPXQP4lWWQfEMsM\u002fls0G596xvD9OfhxkhQzCPzMpdlWTgdM\u002fvA4Y4TnMqT\u002f8HkOF+pXZP+yAs6cojrY\u002fGIskGjJO2j\u002fiU0\u002f8PBSwP8XRGMCbV9Q\u002fpLRlmAsBwT+xCY9XR9K4P0OxIlM7Sp8\u002fUDBGIE922z+7XjDtXu3iP92DgeuVvqY\u002fb1JByyupuj\u002fePr8\u002fRGuyP6veITMn8do\u002fg2X\u002fDoSlzD96vBZ6Ava9PwWlwmNrhKk\u002fiBRyzFc5wz\u002fGrfIwoXS6P8mBYQbLB8E\u002fFtAEIRtgtT90UgqM7RnDP1IruRlvBro\u002fMvUyegvd1T9M56UxCFi\u002fP3sNqYwSq9o\u002fcA99l4zowj93X+3ZuQ2qPzi2z ...
# <div style="height:100%; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="7b2de819-ac12-4054-89b3-f847e0fa2c08" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7b2de819-ac12-4054-89b3-f847e0fa2c08")) {                    Plotly.newPlot(                        "7b2de819-ac12-4054-89b3-f847e0fa2c08",                        [{"boxpoints":false,"hovertemplate":"\u003cb\u003e%{y.name}\u003c\u002fb\u003e\u003cbr\u003eMin: %{y.min:.4f}\u003cbr\u003eQ1: %{y.q1:.4f}\u003cbr\u003eMedian: %{y.median:.4f}\u003cbr\u003eQ3: %{y.q3:.4f}\u003cbr\u003eMax: %{y.max:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#98C21F"},"name":"Control","y":{"dtype":"f8","bdata":"vmD9No\u002fo1j+Rp\u002fmrJNPUP2lsl43H\u002ftY\u002fY5yWXG\u002fIoz88WA4KR7FDPxYw\u002fsOEeKY\u002fsWPFAipD5j9GYdasuiy2PzD07MpNaZI\u002f27q\u002fRQ\u002fZZj+G60Xeb5d3P3GicJu7+Xo\u002fdgYwL8v4jT+mCwJSFzWsP0TWr0NAN98\u002fEwfTOsg1lz9hBVVrfHmEP2T54fOq2sQ\u002f3s9oGhJpaT+PeX0fHuGyPwqMnh4nhqI\u002f0zuATITT3z+FViBohrqWP78Ihi829kE\u002fq3p8f58acT+4q6NwAc4kP3354HyDceI\u002fpOOtnoJxEz\u002fxz7S\u002f61PQPwSi5EaPFuQ\u002fK105ZVdiuz\u002frY2wUVsI3P94NK+NB6zQ\u002f0k+qhfU3rj9kmmVeS\u002fjhP4zA+7TCS3o\u002f0uALHBFj6T\u002ffCKZNmrzePw+jvk+GQeE\u002fJBlIFRRUHj8UtRZvAUqDP2\u002fvPbb9D6Y\u002fyB2JomSQtD+z0uaOprfdP7jkzhtrh2g\u002fbyjjc9FBwj875RZyE5y4P7K9lbocjdw\u002fRnobSj7k5j8d0X2e+up5P4NaKY4oJVc\u002ffaMpEMWvvj9fw+vPBG3KP\u002f8gdNng6OY\u002fKzO6sga\u002fjT9ix3pcm4i6PxA0g\u002fQ2hXI\u002f4VozfhUX3T\u002f1RM9lKDTKP2P+4RY5iHk\u002fAFriiGAktD\u002fPFNrc\u002fGa1P94tlf5SS1A\u002fhByhfhdmrD+2XzGqpcuWPz8q9UECZaw\u002fgqMCW5eX1D9GHjtpd3ykPye+byR\u002fW6w\u002fpHvjUTnLwj+5kOFDRtSGP73grxDNS8k\u002fln0YFxhEoj8pniq2fwNzP++E9\u002fCgn88\u002fp0dXEBF1xD9quUWGye3QPwWFxOTidcs\u002fSnf9oqOJ2z9P9UMrN3rmP461hbyct4I\u002fA23SQdI8hT9klsuzx+rTPzS7B4GlrMQ\u002fu15RKFZh0z7UuYi1cOPXPzggGntYIKI\u002fqyJckAZLaj+kKs9t78wnP7zwa+cxU3I\u002f66uQ0nVb4z+YoS2OO365P1w0Zubq\u002fno\u002fEaUyspueBT8eH0rsCzjnP+BXMpeYzNI\u002fW3F+n2eogD830zKARRx4P665kdlMZrk\u002fLzOCYnhJuz+CpRwErHDGPzNxjd3poeo\u002fyfMfYlKntT9Y4AC95XOIP2shN3Q4j7U\u002fwfoas\u002f9qsD+mOCwrdGLUP2piH2zR1IE\u002fzwI+fMhttD829sRBFsHCP3HpNTZT07k\u002fYDHNAxWYqj9lcfdYq+SOP5BS2njI+tc\u002fQSa5ZGVUnT+EkqTHvpLFP63Rk7W4cOA\u002f32b8lHh1tj8dtSbTT2vHP0wt3q2KBOY\u002fW8NOR9dLdj9dN05mWQG5PzcoRWv+XXE\u002fhwmYaIbp4j7onfapfjjpPykfrtMSUrM\u002fklq7yN7LsD++AJJylNCXPwrkEwSKfI8\u002f4sPXOh+l4T9WgCrYocszP8HQGB7kaUw\u002fEol\u002fcdBmzz8t6oOEcsw4P2xwiFV4TDw\u002fBgu5T6U2bz\u002fA+XyjY0PlP2HnaVWhBKU\u002fNS6uAjPt\u002fT7+nVbYWp17P4Nzx9VZ52I\u002fUq8CISklaz\u002ftwfvqJ6GjP+qhVks910A\u002frjPBlgb+uj\u002fyu0Gk8WvIP4EYbsXjnGo\u002fEOpPZdkb1z\u002fvQInDP5+aP7wq3B6qQpQ\u002fjnera1cJlD+c4tcJUk7KP8p2XoMqrnM\u002fl9hMdZqprz\u002fZ5\u002fmEGa2XPyb67W5aD9c\u002feDzIJKwk0D91j12hpUGXP3N\u002fIAx5bOw\u002ffRJ1x1BE9j5ysloWyPOIP5CARmLuU2E\u002foMVRnCBfUz\u002fRzny8qCeLPwLWxqDh4LQ\u002fvybjipqcvj+VuUa4Xkm6P1OLXQ211ek\u002fSxoGUFY6iz++ZzEfMs5qP74b78p8D6g\u002fBR\u002f41nXafz9UawBnVKjqP3\u002foCXTiXu8\u002fQiBQPufB1D\u002fZAYXSxHnRP1R+dbaahrk\u002fqLHEm5gCtD9lJqYlxSVuP8+8nyknbkg\u002fdny85T3TzT9SMHKYKcf8PuFW2lBV6sE\u002fFbmmOdS4kj92hKUCbO1BP4xB6+4AoFc\u002fP9sIzAoeZD9nen2T85b0Pkb+7aB3OqI\u002fVdfvJ1IQ3D81JsS43kvMP+DRElCt09M\u002f081SyH2eqD+qVy\u002fzzhbnP8JtKdlmNSg\u002fC8OoPa3Vgj\u002fJOdVQ3GNGP+CVk78HZt0\u002fkBDVehCc2z8uRVYZj+rkP5Xz8iH\u002fCmM\u002fknfp1HBYoT9UlEwDfKKNP+JSSI9TK80\u002fE+E7JhUSxj9nABsSh1ffP30Sx2rj0e8\u002fZaAjemIZkT9722zvMcR\u002fP\u002fQSDdpOX4U\u002f5ml0ztjUtD+6yGCBYARhPyPmSYzs76M\u002fm2yqu5Zz7T8rtHBm8orSP+mTS81VeoE\u002fkH3tAnz5qz8jyFvYF6qbPzPf93K9dSI\u002fhfG4wWbHyD\u002f35nSDKVisP9sqiAOK5uk\u002f\u002fiSNPuT2GT+iLFCU7K3IPlaJj5PTKbw\u002fr5T78hSj7T8udNumldmBPzhNjeYVR+U\u002fuwcpvqxkJT86Uq0WZwkwP ...

# %% [markdown]
# ### Remedy when positivity fails: restrict and reweight
#
# When overlap is poor, two complementary fixes from the de-biasing toolkit apply:
#
# - **Restrict (trimming):** drop units with $\hat{\pi}(x) < \varepsilon$ or $\hat{\pi}(x) > 1 - \varepsilon$ and target the *trimmed* population where both arms are plausible.
# - **Reweight (overlap weights):** weight each *treated* unit by $1-\pi(x)$ and each *control* unit by $\pi(x)$ ([Li, Morgan & Zaslavsky, 2018](https://doi.org/10.1080/01621459.2016.1260466)); this per-unit weight is largest where $\pi(x)\approx 0.5$, so it smoothly down-weights non-overlap units and targets the *overlap population* — the group for whom the treatment decision is genuinely uncertain.
#
# Below we estimate the effect under the *violated* regime three ways and compare against the known truth (`ATE = 5.0`). Naive IPW is destabilised by extreme weights; trimming and overlap weighting recover a far more reliable estimate.

# %%
# Work in the VIOLATED-positivity regime and estimate the effect on Y_Violate.
# Y_Violate is the outcome generated from T_Violate_Positivity (same true ATE),
# so the comparison against the known ATE = 5.0 is meaningful.
ps_cols = ['X1', 'X2', 'X3', 'X4', 'X5']
ps_violate = estimate_propensity(data, 'T_Violate_Positivity', ps_cols)

# (a) Naive stabilised IPW on the full sample -> extreme weights
ate_full, w_full = ipw_ate(data, 'T_Violate_Positivity', 'Y_Violate', ps_violate)

# (b) Restrict: trim to the common-support region [eps, 1-eps]
trimmed, ps_trim, keep = trim_common_support(data, ps_violate, eps=0.05)
ate_trim, w_trim = ipw_ate(trimmed, 'T_Violate_Positivity', 'Y_Violate', ps_trim)

# (c) Reweight: overlap weights on the full sample
ate_overlap, w_overlap = overlap_weighted_ate(data, 'T_Violate_Positivity', 'Y_Violate', ps_violate)

summary = pd.DataFrame({
    'Method': ['Naive IPW (full)', 'IPW after trimming', 'Overlap weighting'],
    'ATE estimate': [ate_full, ate_trim, ate_overlap],
    'Max weight': [w_full.max(), w_trim.max(), w_overlap.max()],
    'Units used': [len(data), int(keep.sum()), len(data)],
})
print(f"True ATE = {ATE}\n")
display(summary.round(3))

print(f"\nTrimming removed {int((~keep).sum())} units in the non-overlap region. "
      "Note how the maximum weight collapses and the estimate moves back toward the truth.")
# Out:
# True ATE = 5.0
#                Method  ATE estimate  Max weight  Units used
# 0    Naive IPW (full)         5.892      22.099        1000
# 1  IPW after trimming         4.848      10.243         355
# 2   Overlap weighting         4.919       0.985        1000
# Trimming removed 645 units in the non-overlap region. Note how the maximum weight collapses and the estimate moves back toward the truth.

# %% [markdown]
# ## Assumption 4 — Exchangeability
#
# {prf:ref}`exchangeability` — no unmeasured confounding given $X$ — is the **strongest and least verifiable** assumption. We cannot test it directly, but we can do two things:
#
# 1. **Check balance on the *observed* confounders — before *and* after adjustment.** A Love plot is a *pre-versus-post* comparison ([Austin, 2009](https://doi.org/10.1002/sim.3697); [Stuart, 2010](https://doi.org/10.1214/09-STS313)): it plots the raw standardised mean difference (SMD, {prf:ref}`smd`) for each covariate next to the SMD that *remains* after adjustment. Balance is only confirmed once the **post-adjustment** SMDs fall inside the $|\text{SMD}| < 0.1$ band; the raw SMDs merely show the imbalance the estimator had to correct.
# 2. **Stress-test against the *unobserved*.** Because balance on $X$ says nothing about the hidden confounder $U$, we follow up with **sensitivity analysis** (next section).
#
# The Love plot below contrasts the good-positivity and violated regimes, showing the raw imbalance (open grey circles) against the IPW-adjusted balance (filled green circles). In the good-positivity regime adjustment pulls every covariate inside the threshold; under the severe positivity violation, extreme weights leave residual imbalance that adjustment cannot remove. Good *post-adjustment* balance is necessary but **not sufficient** for exchangeability — it only rules out imbalance in what we measured.

# %%
# A Love plot is a PRE-versus-POST comparison: for each covariate we show the raw
# imbalance and the imbalance that REMAINS after IPW adjustment. Only the
# post-adjustment SMDs falling inside the |SMD| < 0.1 band confirm that the
# estimator achieved balance (Austin 2009; Stuart 2010).
covariates_to_balance = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10']


def love_pre_post(treatment, outcome):
    """Return (raw SMD, IPW-adjusted SMD) for a regime, adjusting on the confounders."""
    ps = estimate_propensity(data, treatment, covariates_adj)
    _, w = ipw_ate(data, treatment, outcome, ps)
    raw = calculate_smd(data, covariates_to_balance, treatment)
    adj = calculate_smd_weighted(data, covariates_to_balance, treatment, w)
    return raw, adj


smd_good_raw, smd_good_adj = love_pre_post('T_Treatment', 'Y')
smd_violate_raw, smd_violate_adj = love_pre_post('T_Violate_Positivity', 'Y_Violate')

# Common x-axis limit across all four series
max_smd_abs = max(smd_good_raw.abs().max(), smd_good_adj.abs().max(),
                  smd_violate_raw.abs().max(), smd_violate_adj.abs().max())
common_x_limit = max_smd_abs + 0.1

fig = sp.make_subplots(rows=1, cols=2, subplot_titles=(
    '1. Good Positivity',
    '2. Severe Violation of Positivity'
))


def add_love_panel(raw, adj, col, show_legend):
    covs = raw.index.tolist()
    fig.add_trace(go.Scatter(
        x=raw, y=covs, mode='markers', name='Raw (before adjustment)',
        marker=dict(color=SAV_GREY, size=10, symbol='circle-open', line=dict(width=2)),
        showlegend=show_legend,
        hovertemplate='Covariate: %{y}<br>SMD (before): %{x:.4f}<extra></extra>'
    ), row=1, col=col)
    fig.add_trace(go.Scatter(
        x=adj, y=covs, mode='markers', name='IPW-adjusted (after)',
        marker=dict(color=SAV_GREEN, size=10, symbol='circle'),
        showlegend=show_legend,
        hovertemplate='Covariate: %{y}<br>SMD (after): %{x:.4f}<extra></extra>'
    ), row=1, col=col)
    fig.add_vline(x=0, line_dash='dash', line_color='gray', line_width=1, row=1, col=col)
    fig.add_vline(x=0.1, line_dash='dash', line_color='red', line_width=1.5, row=1, col=col)
    fig.add_vline(x=-0.1, line_dash='dash', line_color='red', line_width=1.5, row=1, col=col)
    fig.update_xaxes(range=[-common_x_limit, common_x_limit],
                     title_text='Standardised Mean Difference', row=1, col=col)


add_love_panel(smd_good_raw, smd_good_adj, col=1, show_legend=True)
add_love_panel(smd_violate_raw, smd_violate_adj, col=2, show_legend=False)

fig.update_layout(height=500, showlegend=True,
                  legend=dict(orientation='h', yanchor='bottom', y=1.08,
                              xanchor='center', x=0.5))
show(fig)
# Out:
# <div style="height:500px; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="1a0c0e61-d355-46ff-99a4-2fb00f4d9841" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1a0c0e61-d355-46ff-99a4-2fb00f4d9841")) {                    Plotly.newPlot(                        "1a0c0e61-d355-46ff-99a4-2fb00f4d9841",                        [{"hovertemplate":"Covariate: %{y}\u003cbr\u003eSMD (before): %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#7E817E","line":{"width":2},"size":10,"symbol":"circle-open"},"mode":"markers","name":"Raw (before adjustment)","showlegend":true,"x":{"dtype":"f8","bdata":"BUQth8L+2D8BFRUcIS7gP77KoBSoNqi\u002fPqYxBxxowj+cZUSWWOxev1x4J7RpAa+\u002f+z+9hwkftL8zLHKgSCqEvxynZGvAQLk\u002fRLeChyQauz8="},"y":["X1","X2","X3","X4","X5","X6","X7","X8","X9","X10"],"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"Covariate: %{y}\u003cbr\u003eSMD (after): %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#98C21F","size":10,"symbol":"circle"},"mode":"markers","name":"IPW-adjusted (after)","showlegend":true,"x":{"dtype":"f8","bdata":"\u002f3JclURXmT9KNQXNOFmLP6qFS2ABl5+\u002f3i8e\u002fzWWxj\u002fBL7ya+SyPv7feClz3\u002fLG\u002fSeRrMOHfvL80SEJofNq1v4BumN\u002fQwLY\u002f0YF2UQFpuD8="},"y":["X1","X2","X3","X4","X5","X6","X7","X8","X9","X10"],"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"Covariate: %{y}\u003cbr\u003eSMD (before): %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#7E817E","line":{"width":2},"size":10,"symbol":"circle-open"},"mode":"markers","name":"Raw (before adjustment)","showlegend":false,"x":{"dtype":"f8","bdata":"Q3GZWXIH\u002fz\u002f3Z6FAODPeP3UHrsBe1tY\u002fBeygIxBE1D\u002fcVmj3mCXXP7JPmq0wQMA\u002frWnGw6yMnL85K+3phdugP+ar1\u002faKeLU\u002fHgAZJRa7n78="},"y":["X1","X2","X3","X4","X5","X6","X7","X8","X9","X10"],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"hovertemplate":"Covariate: %{y}\u003cbr\u003eSMD (after): %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#98C21F","size":10,"symbol":"circle"},"mode":"markers","name":"IPW-adjusted (after)","showlegend":false,"x":{"dtype":"f8","bdata":"aFLh4RET3D8GxZnALlPDvzsBTqH2Fu4\u002fxFekllZa6T8uoE08aaTwP1lTtV\u002fOL7U\u002f0W6JEx1vvr9Gfr1e52e9v8tiyYRYLXO\u002fy5EkNjBix78="},"y":["X1","X2","X3","X4","X5","X6","X7","X8","X9","X10"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour": ...

# %% [markdown]
# ## Sensitivity Analysis for Unmeasured Confounding
#
# Balanced covariates do not prove exchangeability — our data still contains the hidden confounder $U$. Since we cannot adjust for what we do not observe, we instead quantify **how robust** the estimated effect is to a plausible unmeasured confounder, using the four tools from {doc}`../tutorial/sensitivity`:
#
# - **E-value** — the minimum strength (on a risk-ratio scale) an unmeasured confounder would need with *both* $T$ and $Y$ to explain the effect away.
# - **Partial $R^2$ / robustness value** (Cinelli & Hazlett) — benchmarked against observed covariates.
# - **Rosenbaum bounds** — the critical odds-of-assignment ratio $\Gamma$ at which significance is lost.
# - **Placebo / negative-control test** — the treatment should show *no* effect on an outcome it cannot affect.
#
# We start from the regression-adjusted estimate (adjusting for the observed confounders $X_1, X_2$ but **not** $U$).

# %%
# Regression-adjusted effect of the programme (adjusting for observed X only)
effect = ols_treatment_effect(data, outcome='Y', treatment='T_Treatment',
                              covariates=covariates_adj)
print(f"Adjusted effect estimate : {effect['coef']:.3f}  (SE {effect['se']:.3f}, "
      f"t = {effect['t']:.2f}, p = {effect['p']:.1e})")
print(f"True ATE                 : {ATE}   <- bias remains because U is unobserved\n")

# --- E-value (VanderWeele & Ding) ---
ev = e_value_from_effect(effect['coef'], effect['se'], sd_outcome=data['Y'].std())
print(f"E-value (point estimate) : {ev['e_value']:.2f}")
print(f"E-value (CI limit)       : {ev['e_value_ci']:.2f}")

# --- Robustness value (Cinelli & Hazlett) ---
rv = robustness_value(effect['t'], effect['dof'])
print(f"Robustness value (RV)    : {rv:.3f}")
print(f"\nReading: an unmeasured confounder would need a partial R-squared of at least "
      f"{rv:.1%} with BOTH treatment and outcome to drive the effect to zero, or an "
      f"association of at least RR = {ev['e_value']:.2f} with each. Larger values = more robust.")
# Out:
# Adjusted effect estimate : 6.785  (SE 0.183, t = 37.12, p = 0.0e+00)
# True ATE                 : 5.0   <- bias remains because U is unobserved
#
# E-value (point estimate) : 7.87
# E-value (CI limit)       : 7.25
# Robustness value (RV)    : 0.673
#
# Reading: an unmeasured confounder would need a partial R-squared of at least 67.3% with BOTH treatment and outcome to drive the effect to zero, or an association of at least RR = 7.87 with each. Larger values = more robust.

# %% [markdown]
# ### Partial $R^2$ contours, benchmarked against observed covariates
#
# The contour plot below ({prf:ref}`partial-r2`) shows the bias-adjusted estimate across a grid of confounder strengths $(R^2_{T \sim U}, R^2_{Y \sim U})$. The thick black line marks where the effect would be driven to **zero**. The dark grey diamond benchmarks "an unmeasured confounder *as strong as the observed covariate* $X_2$" — if that point sits far from the zero line, even a confounder of that strength would not overturn the conclusion.

# %%
# Benchmark: how strongly is the observed covariate X2 associated with T and Y?
def _partial_r2(df, target, focal, others):
    res = ols_treatment_effect(df, outcome=target, treatment=focal, covariates=others)
    return res['t'] ** 2 / (res['t'] ** 2 + res['dof'])

others_x2 = [c for c in covariates_adj if c != 'X2']
r2_x2_y = _partial_r2(data, 'Y', 'X2', ['T_Treatment'] + others_x2)
r2_x2_t = _partial_r2(data, 'T_Treatment', 'X2', others_x2)
print(f"Observed covariate X2 — partial R² with Y: {r2_x2_y:.3f}, with T: {r2_x2_t:.3f}")

benchmark = {'r2_tu': r2_x2_t, 'r2_yu': r2_x2_y, 'label': 'as strong as X2'}
fig = plot_sensitivity_contour(effect['coef'], effect['se'], effect['dof'],
                               title='Partial R² sensitivity contours',
                               benchmark=benchmark)
show(fig)
# Out:
# Observed covariate X2 — partial R² with Y: 0.101, with T: 0.046
# <div style="height:100%; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="6650b062-ac49-4751-9958-eef5561858ae" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6650b062-ac49-4751-9958-eef5561858ae")) {                    Plotly.newPlot(                        "6650b062-ac49-4751-9958-eef5561858ae",                        [{"colorbar":{"title":{"text":"Adjusted\u003cbr\u003eeffect"}},"colorscale":[[0.0,"#5F625F"],[0.5,"#EDEDEA"],[1.0,"#98C21F"]],"contours":{"showlabels":true},"x":{"dtype":"f8","bdata":"AAAAAAAAAAAf+IEf+IGPPx\u002f4gR\u002f4gZ8\u002fF3qhF3qhpz8f+IEf+IGvPxM7sRM7sbM\u002fF3qhF3qhtz8buZEbuZG7Px\u002f4gR\u002f4gb8\u002fkRu5kRu5wT8TO7ETO7HDP5VaqZVaqcU\u002fF3qhF3qhxz+ZmZmZmZnJPxu5kRu5kcs\u002fndiJndiJzT8f+IEf+IHPP9ALvdALvdA\u002fkRu5kRu50T9SK7VSK7XSPxM7sRM7sdM\u002f1Eqt1Eqt1D+VWqmVWqnVP1ZqpVZqpdY\u002fF3qhF3qh1z\u002fYiZ3YiZ3YP5mZmZmZmdk\u002fWqmVWqmV2j8buZEbuZHbP9zIjdzIjdw\u002fndiJndiJ3T9e6IVe6IXePx\u002f4gR\u002f4gd8\u002f8AM\u002f8AM\u002f4D\u002fQC73QC73gP7ETO7ETO+E\u002fkRu5kRu54T9yIzdyIzfiP1IrtVIrteI\u002fMzMzMzMz4z8="},"y":{"dtype":"f8","bdata":"AAAAAAAAAAAf+IEf+IGPPx\u002f4gR\u002f4gZ8\u002fF3qhF3qhpz8f+IEf+IGvPxM7sRM7sbM\u002fF3qhF3qhtz8buZEbuZG7Px\u002f4gR\u002f4gb8\u002fkRu5kRu5wT8TO7ETO7HDP5VaqZVaqcU\u002fF3qhF3qhxz+ZmZmZmZnJPxu5kRu5kcs\u002fndiJndiJzT8f+IEf+IHPP9ALvdALvdA\u002fkRu5kRu50T9SK7VSK7XSPxM7sRM7sdM\u002f1Eqt1Eqt1D+VWqmVWqnVP1ZqpVZqpdY\u002fF3qhF3qh1z\u002fYiZ3YiZ3YP5mZmZmZmdk\u002fWqmVWqmV2j8buZEbuZHbP9zIjdzIjdw\u002fndiJndiJ3T9e6IVe6IXePx\u002f4gR\u002f4gd8\u002f8AM\u002f8AM\u002f4D\u002fQC73QC73gP7ETO7ETO+E\u002fkRu5kRu54T9yIzdyIzfiP1IrtVIrteI\u002fMzMzMzMz4z8="},"z":{"dtype":"f8","bdata":"CpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQAqSHbU\u002fJBtACpIdtT8kG0AKkh21PyQbQNnYF6+pyBpAhWAi57OhGkDPj\u002fw0FIMaQNmVkmqgaBpASnx9b71QGkAGexrjmDoaQBxqwby1JRpA9W\u002fZOcIRGkCeYqglhf4ZQFx1AV3U6xlAh0ociI\\u002f\u002f2RdAyNDFrge\u002fF0DZVeyH5KIXQAqSHbU\u002fJBtA\u002f0nlBbqiGkCUgm\u002f3oGsaQKjcWPZRQBpA1x0+NOkaGkBP07dQIfkZQB8Q\u002fcbQ2RlAVzX6w0a8GUDgsVmnD6AZQEHvVYrahBlAsWqQ1WtqGUC1nafLlVAZQMAfUBY0NxlA3XE8+CgeGUC1kEZzWwUZQHNxfgO27BhA1pGuuCXUGECCYMyNmbsYQGGCF+oBoxhAY4nfPlCKGEB4vEa5dnEYQEvjEwJoWBhAodpkBxc\u002fGECY6zfNdiUYQP\u002fOgkJ6CxhApeINGRTxF0AJO52eNtYXQKvZJJbTuhdAZWXhD9yeF0C\u002fETg\u002fQIIXQDRzOU3vZBdAaKqMJtdGF0CXCGJD5CcXQEws1GcBCBdAJznRWhfnFkC7GD6RDMUWQDpCfMrEoRZAVOnEmiB9FkDa9tve\...\u002fy4nGSgfGkCTjdu06OEZQKeZByABrRlAimbdKTt9GUACZBcR8lAZQC1CZcQrJxlA4E2VvkT\u002fGEAyMzOWytgYQK5Y5QRpsxhABQMbW9+OGEBu02U1+moYQILI74SPRxhAubNf8XskGEAHJU8NoQEYQNz0VhDk3hdA3LKt6Cy8F0Dk9biHZZkXQAIkI1d5dhdAqto1ylRTF0BoHRYD5S8XQBfC+IUXDBdAXtAC9tnnFkCXY5rYGcMWQMgWoVzEnRZAHpeGI8Z3FkCs+GoKC1EWQAkgsPF9KRZAZr5mgQgBFkBdj\u002fnoktcVQDz0WZgDrRVAoeW68D6BFUA+0JfqJlQVQCCKV66aJRVAQORIHHb1FEAT\u002fvM\u002fkcMUQBupuqm\u002fjxRAhg9uqM9ZFECoGbtaiSEUQAqSHbU\u002fJBtAMaYZznRXGkDbdKjAVgAaQJkS3qjcuxlAjYOwebaAGUA3TG72TEsZQEsf\u002frPJGRlA56PXHBXrGEDC9b1eeL4YQGAQFo9zkxhAwaoEdahpGECumWG+zkAYQFLD9PasGBhApeINGRTxF0AijFCg3MkXQNlV7IfkohdATTcw3g18F0DW4AW6PVUXQPAwVXJbLhdAQ2+0AlAHF0DYUrOPB ...

# %% [markdown]
# ### Rosenbaum bounds (matched design)
#
# For a matched analysis, {prf:ref}`rosenbaum-gamma` asks: how much could the odds of treatment differ between two units with identical observed covariates — because of a hidden confounder — before our conclusion breaks? We form 1:1 propensity-score-matched pairs, then trace the **worst-case p-value** as $\Gamma$ grows. The **critical $\Gamma$** (the value at which the worst-case curve *crosses* $\alpha = 0.05$) is the headline robustness number: the larger it is, the more hidden bias the finding can absorb. Because the worst-case $p$-value rises monotonically with $\Gamma$, we extend the grid until it actually crosses $\alpha$; if it never does within the tested range, the critical $\Gamma$ is reported only as a **censored lower bound** ("$\geq$ grid endpoint"), never as the grid endpoint itself ([Rosenbaum, 2002](https://doi.org/10.1007/978-1-4757-3692-2)).
#
# Unlike the E-value and robustness value above — which characterise the *regression* estimate — this bound is computed on a **different estimator**: the 1:1 propensity-score-matched pairs, whose mean difference is the matched **ATT**. The critical $\Gamma$ therefore reports the robustness of the matched-pair ATT, not of the regression coefficient; the two answer the same question for two distinct estimands and should not be conflated.

# %%
# 1:1 nearest-neighbour matching on the estimated propensity score
ps_good = estimate_propensity(data, 'T_Treatment', covariates_adj)
treated_mask = data['T_Treatment'].values == 1
y_all = data['Y'].values

ctrl_ps = ps_good[~treated_mask]
ctrl_y = y_all[~treated_mask]
treat_ps = ps_good[treated_mask]
treat_y = y_all[treated_mask]

# Optimal 1:1 matching WITHOUT replacement: solve the assignment problem on the
# |propensity| distance matrix so every treated unit gets a *distinct* control.
# Rosenbaum's sensitivity analysis assumes independent matched pairs; reusing a
# control across pairs would correlate the pair differences and invalidate the
# permutation distribution of the signed-rank statistic.
from scipy.optimize import linear_sum_assignment

cost = np.abs(treat_ps[:, None] - ctrl_ps[None, :])
treat_idx, ctrl_idx = linear_sum_assignment(cost)

# Matched-pair outcome differences (treated - matched control)
pair_diffs = treat_y[treat_idx] - ctrl_y[ctrl_idx]

# The worst-case p-value rises monotonically with Γ. Extend the grid until the
# curve actually crosses α, so the reported critical Γ is a genuine crossing and
# not the grid endpoint (which would understate a very robust finding).
alpha = 0.05
gammas = np.round(np.arange(1.0, 4.01, 0.5), 2)
bounds = rosenbaum_sensitivity(pair_diffs, gammas)
while bounds['p_upper_bound'].iloc[-1] < alpha and gammas[-1] < 25:
    gammas = np.round(np.arange(1.0, gammas[-1] + 4.01, 0.5), 2)
    bounds = rosenbaum_sensitivity(pair_diffs, gammas)

if (bounds['p_upper_bound'] >= alpha).any():
    critical_gamma = bounds.loc[bounds['p_upper_bound'] < alpha, 'Gamma'].max()
    print(f"Critical Γ (worst-case p-value first crosses α = {alpha}): {critical_gamma}")
else:
    critical_gamma = None
    print(f"Worst-case p-value stays below α = {alpha} across the whole tested grid "
          f"(up to Γ = {gammas[-1]}): significance is retained to *at least* this value — "
          "a censored lower bound, so the true critical Γ lies beyond the tested range.")
display(bounds.round(4))

show(plot_rosenbaum(bounds, alpha=0.05))
# Out:
# Critical Γ (worst-case p-value first crosses α = 0.05): 18.0
#     Gamma  p_upper_bound
# 0     1.0         0.0000
# 1     1.5         0.0000
# 2     2.0         0.0000
# 3     2.5         0.0000
# 4     3.0         0.0000
# 5     3.5         0.0000
# 6     4.0         0.0000
# 7     4.5         0.0000
# 8     5.0         0.0000
# 9     5.5         0.0000
# 10    6.0         0.0000
# 11    6.5         0.0000
# 12    7.0         0.0000
# 13    7.5         0.0000
# 14    8.0         0.0000
# 15    8.5         0.0000
# 16    9.0         0.0001
# 17    9.5         0.0001
# 18   10.0         0.0003
# 19   10.5         0.0005
# 20   11.0         0.0008
# 21   11.5         0.0013
# 22   12.0         0.0020
# 23   12.5         0.0030
# 24   13.0         0.0043
# 25   13.5         0.0060
# 26   14.0         0.0081
# 27   14.5         0.0108
# 28   15.0         0.0140
# 29   15.5         0.0179
# 30   16.0         0.0225
# 31   16.5         0.0278
# 32   17.0         0.0339
# 33   17.5         0.0409
# 34   18.0         0.0486
# 35   18.5         0.0571
# 36   19.0         0.0665
# 37   19.5         0.0767
# 38   20.0         0.0877
# <div style="height:100%; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="f908d6bc-768f-4cc7-82c2-63b6475155a0" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f908d6bc-768f-4cc7-82c2-63b6475155a0")) {                    Plotly.newPlot(                        "f908d6bc-768f-4cc7-82c2-63b6475155a0",                        [{"line":{"color":"#98C21F","width":2},"mode":"lines+markers","name":"Worst-case p-value","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQBc9AAAAAICEgD0AAAAATCXRPQAAAKBhmxE+AAAA+H+pRT4AAIB3GyRyPgAAYHevmJY+AABAQ3dMtj4AAG6tBkPSPgAAkBMntOk+AIDe49Dt\u002fz4AQFgFZN4RPwDQ9ZSoUSI\u002fAFjui+NtMT8AsIrgqxs\u002fPwD8o+dGREo\u002fAOIiu+oiVT8ADj7aaU5gPwBpRVBoPmg\u002fgKnP7MhwcT8AoRYoCl94P0DAvb8Pl4A\u002fAGOZAaIQhj8AfafQbryMP8CjMQ0wXJI\u002f4Ad6N6sPlz\u002fgJtgORoScP5BY8pLHYaE\u002fILC3Dm\u002fqpD9QcnjHnt6oP\u002fBoEuCyP60\u002fAI6Ji\u002fEGsT+gyCbvJqSzP3ALJE+EdrY\u002f"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","mar ...

# %% [markdown]
# ### Placebo / negative-control test
#
# A final falsification check ({prf:ref}`placebo-test`): apply the *same* estimator to a **negative-control outcome** — one the programme cannot plausibly affect, but which shares the confounding structure. If exchangeability (given $X$) held, the estimated "effect" on this outcome should be **zero**. A non-zero estimate is a red flag for residual confounding.
#
# Here the negative control is driven by $X_1, X_2$ and the hidden $U$ but **not** by $T$. Because $U$ is omitted from the adjustment set, the test should detect the leakage — demonstrating exactly how a placebo test surfaces unmeasured confounding.

# %%
# Real outcome vs. negative-control outcome, same estimator and adjustment set
real = ols_treatment_effect(data, 'Y', 'T_Treatment', covariates_adj)
placebo = negative_control_test(data, 'Y_Negative_Control', 'T_Treatment', covariates_adj)

placebo_tbl = pd.DataFrame({
    'Outcome': ['Y (real)', 'Y_Negative_Control (placebo)'],
    'Estimated effect': [real['coef'], placebo['coef']],
    'Std. Error': [real['se'], placebo['se']],
    'p-value': [real['p'], placebo['p']],
    'Expected': ['≈ true ATE', '≈ 0 if exchangeable'],
})
display(placebo_tbl.round(3))

if placebo['p'] < 0.05:
    print(f"\nThe placebo effect is significantly non-zero (p = {placebo['p']:.1e}) -> "
          "residual (unmeasured) confounding is present, consistent with the hidden U. "
          "Remedy: seek a richer adjustment set, an instrument, or report the sensitivity "
          "bounds above alongside the estimate.")
else:
    print(f"\nThe placebo effect is not distinguishable from zero (p = {placebo['p']:.2f}) -> "
          "no evidence of residual confounding from this test.")
# Out:
#                         Outcome  Estimated effect  Std. Error  p-value  \
# 0                      Y (real)             6.785       0.183      0.0
# 1  Y_Negative_Control (placebo)             1.005       0.178      0.0
#
#               Expected
# 0           ≈ true ATE
# 1  ≈ 0 if exchangeable
# The placebo effect is significantly non-zero (p = 2.3e-08) -> residual (unmeasured) confounding is present, consistent with the hidden U. Remedy: seek a richer adjustment set, an instrument, or report the sensitivity bounds above alongside the estimate.

# %% [markdown]
# ```{note} Summary — what this notebook demonstrated
# :class: dropdown
#
# - ✅ **Causal graph** encoded (identifiable vs. unobserved-confounder case).
# - ✅ **Consistency** probed by re-estimating the effect per treatment sub-type.
# - ✅ **SUTVA** probed by correlating control outcomes with neighbours' treatment intensity.
# - ✅ **Positivity** assessed via propensity overlap, then *restored* by trimming and overlap weighting.
# - ✅ **Exchangeability** checked for observed balance (SMD / Love plot) and stress-tested with **E-values, partial $R^2$ contours, Rosenbaum bounds, and a placebo test**.
# ```
#
# ## Reality Check: LaLonde (1986) revisited
#
# How well do these diagnostics actually substitute for a randomized experiment? The canonical stress-test is [LaLonde (1986)](https://www.jstor.org/stable/1806062), who took a job-training RCT (the *National Supported Work* programme), threw away the experimental control group, and tried to recover the known experimental benchmark from *nonexperimental* comparison groups. His verdict was sobering: the econometric methods of the day **could not systematically replicate the experimental estimate** — a result that cast a long shadow over observational causal inference.
#
# [Imbens & Xu (2024)](https://doi.org/10.48550/arXiv.2406.00827) revisit that same data four decades later, asking what the methods developed since have actually bought us. Their reassessment maps almost one-to-one onto the four {doc}`identification assumptions <../tutorial/assumptions>` and the {doc}`diagnostics and sensitivity checks <../tutorial/diagnostics>` used in this notebook:
#
# - **Separate unconfoundedness from functional form.** Much of LaLonde's original failure came from extrapolating linear models into regions with no comparable units — *not* from {prf:ref}`exchangeability` per se. Stating the adjustment set on a DAG, independent of the regression specification, is the modern discipline (our step 1).
# - **Overlap is decisive.** When the treated and comparison groups genuinely overlap in covariate space, modern estimators (propensity-score and **doubly robust** methods) recover *stable, robust* adjusted differences. Where overlap is poor, no estimator rescues the comparison — exactly the failure that {prf:ref}`positivity` and its {prf:ref}`balance diagnostics <smd>` (box/mirror and Love plots) are designed to catch, with trimming/overlap-weighting as the remedy.
# - **Robust ≠ causal.** Their sharpest warning: an estimate can be numerically stable and pass goodness-of-fit checks while still being **biased by unmeasured confounding**. Goodness-of-fit tells you nothing about {prf:ref}`exchangeability`; only a {prf:ref}`sensitivity analysis <e-value>` ({prf:ref}`E-values <e-value>`, {prf:ref}`partial $R^2$ <partial-r2>`, {prf:ref}`Rosenbaum bounds <rosenbaum-gamma>`) quantifies how much hidden bias the conclusion could absorb.
# - **Validation exercises are essential.** What *does* probe credibility is out-of-sample validation against an experimental or {prf:ref}`placebo / negative-control <placebo-test>` benchmark — precisely the falsification test we ran above, and the reason our placebo correctly flags the hidden confounder $U$.
#
# The throughline is reassuring for the careful analyst: the four-assumption discipline of this notebook — *inspect the assignment process, scrutinise overlap, and validate rather than assume* — is exactly the toolkit that turns LaLonde's pessimism into the qualified, defensible estimates Imbens & Xu obtain.
#
# ## Takeaways for the actuary
#
# ```{admonition} A practical workflow for observational data
# :class: tip
#
# 1. **Draw the DAG first.** State the treatment, the outcome, and the adjustment set *before* looking at estimates — this fixes which variables are confounders, mediators, or colliders, and keeps {prf:ref}`exchangeability` separate from the functional form of any model.
# 2. **Diagnose, don't assume.** {prf:ref}`consistency`, {prf:ref}`sutva` and {prf:ref}`positivity` leave footprints in the data; run the corresponding check rather than taking them on faith.
# 3. **Make overlap the gatekeeper.** LaLonde's reanalysis shows estimates are only trustworthy where the treated and control groups genuinely overlap. Inspect $\hat{\pi}(x)$ and the {prf:ref}`balance diagnostics <smd>`, then **trim or reweight** to the common-support population before reporting anything.
# 4. **Robust is not the same as causal.** A stable estimate that passes goodness-of-fit can still be confounded. Treat {prf:ref}`exchangeability` as a matter of degree, and pair each estimator with the sensitivity metric built for it: the {prf:ref}`E-value <e-value>` and {prf:ref}`robustness value / partial $R^2$ <partial-r2>` quantify the robustness of the *regression* estimate, whereas the {prf:ref}`critical $\Gamma$ <rosenbaum-gamma>` quantifies that of a *matched design* (the matched-pair ATT) — a different estimator, so a $\Gamma$ computed on matched pairs must not be read as the robustness of a regression coefficient. Add a {prf:ref}`validation / placebo test <placebo-test>` against a benchmark the treatment cannot affect.
# 5. **Match the remedy to the violation.** Redefine an ambiguous treatment; model spillovers at the group level; trim or reweight to fix positivity; enrich the adjustment set or use an instrument for hidden confounding. Where no assumption pins the effect down, report worst-case {prf:ref}`Manski bounds <manski-bounds>`.
# 6. **Report transparently.** A decision-maker is far better served by *"effect = X, robust to a confounder up to strength Y"* than by a single unqualified number.
# ```
#
# **The bottom line.** Observational data can support credible causal statements, but **only when each identification assumption is explicitly checked and, where needed, repaired**. The four-decade reassessment of [LaLonde (1986)](https://www.jstor.org/stable/1806062) by [Imbens & Xu (2024)](https://doi.org/10.48550/arXiv.2406.00827) sharpens the practical discipline for the actuary moving from prediction to causal inference: in an actuarial causal-inference setting, **the assumption checks _are_ the analysis** — and the estimate is only as trustworthy as the overlap, diagnostics, and validation bounds reported alongside it.
